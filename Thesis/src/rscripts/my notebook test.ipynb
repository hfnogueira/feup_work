# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# generate random data
x = np.random.randn(100)
y = np.random.randn(100)

# plot the data
plt.scatter(x, y)
plt.show()
